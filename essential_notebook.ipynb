# %%
import torch

# %%
a = torch.tensor([[1., -1.], [1., -1.]])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-72a30dcda170> in <module>
# ----> 1 a = torch.tensor([[1., -1.], [1., -1.]])
#
# AttributeError: module 'torch' has no attribute 'tensor'
